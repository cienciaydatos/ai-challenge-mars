# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#cd /content/gdrive/My Drive/Colab Notebooks/Omdena_Mars_Anomaly_Detection
#from Feature_extractor import Feature_extractor
#from Clusterer import Clusterer

# %%
### Rishika folder
folder="/content/gdrive/My Drive/Colab Notebooks/Omdena_Mars_Anomaly_Detection"

# %%
### Luiz folder
folder="/content/gdrive/My Drive/Omdena_Mars_Anomaly_Detection"

# %%
import numpy as np 
import pandas as pd 
import os
from tqdm import tqdm, trange, tqdm_notebook
from sklearn.metrics import roc_auc_score
import pickle
import gc
import torch.nn.functional as F

# %%
import sys
### Append the folder to the path
sys.path.append(folder)

### import libraries (from 'folder')
from Clusterer import *
from Feature_extractor import *
from purity import *

# %%
dataset = "Images"
cnn_architecture  = "xception"
layer  = "avg_pool"
clustering_algorithm = "mb_kmeans"
metric = "both"

# %%
fe = Feature_extractor(dataset, cnn_architecture, layer)
fe.extract_and_save_features()
# Out:
# Feature extractor: xception // avg_pool

# %%
cl = Clusterer(dataset, cnn_architecture, layer, clustering_algorithm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-73f0184f359c> in <module>()
# ----> 1 cl = Clusterer(dataset, cnn_architecture, layer, clustering_algorithm)
#
# /content/gdrive/My Drive/Omdena_Mars_Anomaly_Detection/Clusterer.py in __init__(self, dataset, cnn_architecture, layer, clustering_algorithm, n_classes)
#      14                 print("dataset_path: " + str(self.dataset_path))
#      15                 print("dataset_feat_path: " + str(self.dataset_feat_path))
# ---> 16
#      17         self.n_files = len(glob(self.dataset_feat_path + "*.p"))
#      18         print("length", len(self.n_files))
#
# TypeError: object of type 'int' has no len()

# %%
cl.cluster()
# Out:
# Clustering ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c834633e31c5> in <module>()
# ----> 1 cl.cluster()
#
# <ipython-input-7-7d665b83c34e> in cluster(self)
#     110         def cluster(self):
#     111                 print("Clustering ...")
# --> 112                 self.predicted_labels = self.algorithm.fit_predict(self.features)
#     113
#     114         def evaluate(self, metric):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py in fit_predict(self, X, y, sample_weight)
#     993             Index of the cluster each sample belongs to.
#     994         """
# --> 995         return self.fit(X, sample_weight=sample_weight).labels_
#     996
#     997     def fit_transform(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#    1489         random_state = check_random_state(self.random_state)
#    1490         X = check_array(X, accept_sparse="csr", order='C',
# -> 1491                         dtype=[np.float64, np.float32])
#    1492         n_samples, n_features = X.shape
#    1493         if n_samples < self.n_clusters:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
predicted_labels = cl.predicted_labels
print("Shape predicted labels: %s" % str(predicted_labels.shape))
cl.evaluate(metric)
